# %%
import pandas as pd
import wandb

wandb.login()
# Out:
# wandb: Currently logged in as: jeroenbe. Use `wandb login --relogin` to force relogin
# True

# %%
api = wandb.Api()

runs = api.runs("jeroenbe/structure-learning")

total_list = []
for run in runs:
    total_list.append({'name': run.name, **dict(run.summary._json_dict),**dict(run.config.items())})
    
run_df = pd.DataFrame(total_list)

# %%
group_df = run_df.groupby(['d', 'n', 'model', 'graph_type', 's0', 'sem_type'])

# %%
group_df.mean()
# Out:
#                                            fdr_normalised  nnz_normalised  \
# d  n    model      graph_type s0 sem_type
# 10 1000 dagma-np   ER         20 gauss                NaN             NaN
#         ges        ER         20 gauss           0.420911       23.545455
#         notears-np ER         20 gauss           0.690058       18.333333
# 20 1000 dagma      ER         20 gauss           0.452239       18.466667
#         dagma-np   ER         20 gauss                NaN             NaN
#         ges        ER         20 gauss           0.030222       20.350000
#                                  mlp             0.248795       18.550000
#         notears    ER         20 gauss           0.529587       18.733333
#                                  mlp             0.503889        9.600000
#         notears-np ER         20 gauss           0.714020       28.500000
#                                  mlp             0.472920       19.166667
# 30 1000 dagma      ER         20 gauss           0.448874       21.400000
#         dagma-np   ER         20 gauss                NaN             NaN
#         ges        ER         20 gauss           0.006818       20.100000
#                                  mlp             0.160499       17.100000
#         notears    ER         20 gauss           0.459466       20.000000
#         notears-np ER         20 gauss           0.666923       25.500000
#
#                                                  shd        nnz       tpr  \
# d  n    model      graph_type s0 sem_type
# 10 1000 dagma-np   ER         20 gauss           NaN        NaN       NaN
#         ges        ER         20 gauss     14.272727  23.545455  0.631818
#         notears-np ER         20 gauss      1.666667  19.333333  0.933333
# 20 1000 dagma      ER         20 gauss      0.466667  20.200000  0.986667
#         dagma-np   ER         20 gauss           NaN        NaN       NaN
#         ges        ER         20 gauss      0.800000  20.350000  0.982500
#                                  mlp       10.700000  18.550000  0.672500
#         notears    ER         20 gauss      0.533333  19.666667  0.973333
#                                  mlp       12.000000  10.900000  0.465000
#         notears-np ER         20 gauss      0.500000  20.000000  0.975000
#                                  mlp        9.000000  18.583333  0.737500
# 30 1000 dagma      ER         20 gauss      1.000000  20.400000  0.970000
#         dagma-np   ER         20 gauss           NaN        NaN       NaN
#         ges        ER         20 gauss      0.150000  20.100000  0.997500
#                                  mlp        8.200000  17.100000  0.715000
#         notears    ER         20 gauss      0.500000  19.500000  0.975000
#         notears-np ER         20 gauss      1.500000  20.500000  0.950000
#
#                                                _runtime       fdr     _step  \
# d  n    model      graph_type s0 sem_type
# 10 1000 dagma-np   ER         20 gauss         0.809174       NaN  0.000000
#         ges        ER         20 gauss        11.187246  0.420911  3.909091
#         notears-np ER         20 gauss      9957.006752  0.035088  3.000000
# 20 1000 dagma      ER         20 gauss         9.131094  0.022381  3.333333
#         dagma-np   ER         20 gauss         1.594671       NaN  0.000000
#         ges        ER         20 gauss        57.885332  0.030222  3.500000
#                                  mlp          54.460323  0.248795  4.000000
#         notears    ER         20 gauss        12.329554  0.010175  3.333333
#                                  mlp          17.050409  0.132302  3.000000
#         notears-np ER         20 gauss      8042.296272  0.025000  2.000000
#                                  mlp       15468.096683  0.191728  2.571429
# 30 1000 dagma      ER         20 gauss        12.683891  0.048095  4.000000
#         dagma-np   ER         20 gauss         1.552427       NaN  0.000000
#         ges        ER         20 gauss       131.878242  0.006818  3.500000
#                                  mlp         104.702381  0.160499  4.000000
#         notears    ER         20 gauss        37.068150  0.000000  3.000000
#         notears-np ER         20 gauss      4831.019358  0.071429  1.500000
#
#                                                 fpr    _timestamp  \
# d  n    model      graph_type s0 sem_type
# 10 1000 dagma-np   ER         20 gauss          NaN  1.696588e+09
#         ges        ER         20 gauss     0.436364  1.696608e+09
#         notears-np ER         20 gauss     0.026667  1.696510e+09
# 20 1000 dagma      ER         20 gauss     0.002745  1.696659e+09
#         dagma-np   ER         20 gauss          NaN  1.696528e+09
#         ges        ER         20 gauss     0.004118  1.696607e+09
#                                  mlp       0.030000  1.696610e+09
#         notears    ER         20 gauss     0.001176  1.696605e+09
#                                  mlp       0.009412  1.696581e+09
#         notears-np ER         20 gauss     0.002941  1.696467e+09
#                                  mlp       0.022549  1.696716e+09
# 30 1000 dagma      ER         20 gauss     0.002410  1.696922e+09
#         dagma-np   ER         20 gauss          NaN  1.696649e+09
#         ges        ER         20 gauss     0.000361  1.696629e+09
#                                  mlp       0.006747  1.696612e+09
#         notears    ER         20 gauss     0.000000  1.696531e+09
#         notears-np ER         20 gauss     0.003614  1.696547e+09
#
#                                            tpr_normalised  DAG-diff  \
# d  n    model      graph_type s0 sem_type
# 10 1000 dagma-np   ER         20 gauss                NaN       NaN
#         ges        ER         20 gauss           0.631818       0.0
#         notears-np ER         20 gauss           0.283333       NaN
# 20 1000 dagma      ER         20 gauss           0.503333      13.2
#         dagma-np   ER         20 gauss                NaN       NaN
#         ges        ER         20 gauss           0.982500       0.0
#                                  mlp             0.672500       0.0
#         notears    ER         20 gauss           0.440000      14.8
#                                  mlp             0.235000       NaN
#         notears-np ER         20 gauss           0.400000       NaN
#                                  mlp             0.475000       NaN
# 30 1000 dagma      ER         20 gauss           0.590000      11.2
#         dagma-np   ER         20 gauss                NaN       NaN
#         ges        ER         20 gauss           0.997500       0.0
#                                  mlp             0.715000       0.0
#         notears    ER         20 gauss           0.540000       NaN
#         notears-np ER         20 gauss           0.425000       NaN
#
#                                            shd_normalised  fpr_normalised  \
# d  n    model      graph_type s0 sem_type
# 10 1000 dagma-np   ER         20 gauss                NaN             NaN
#         ges        ER         20 gauss          14.272727        0.436364
#         notears-np ER         20 gauss          20.000000        0.506667
# 20 1000 dagma      ER         20 gauss          11.933333        0.049412
#         dagma-np   ER         20 gauss                NaN             NaN
#         ges        ER         20 gauss           0.800000        0.004118
#                                  mlp            10.700000        0.030000
#         notears    ER         20 gauss          14.533333        0.058431
#                                  mlp            16.700000        0.028824
#         notears-np ER         20 gauss          23.000000        0.120588
#                                  mlp            16.000000        0.056863
# 30 1000 dagma      ER         20 gauss          10.600000        0.023133
#         dagma-np   ER         20 gauss                NaN             NaN
#         ges        ER         20 gauss           0.150000        0.000361
#                                  mlp             8.200000        0.006747
#         notears    ER         20 gauss          10.500000        0.022169
#         notears-np ER         20 gauss          18.000000        0.040964
#
#                                            run_count
# d  n    model      graph_type s0 sem_type
# 10 1000 dagma-np   ER         20 gauss     10.000000
#         ges        ER         20 gauss     10.000000
#         notears-np ER         20 gauss     10.000000
# 20 1000 dagma      ER         20 gauss      8.333333
#         dagma-np   ER         20 gauss     10.000000
#         ges        ER         20 gauss     10.000000
#                                  mlp       10.000000
#         notears    ER         20 gauss      8.333333
#                                  mlp       10.000000
#         notears-np ER         20 gauss     10.000000
#                                  mlp       10.000000
# 30 1000 dagma      ER         20 gauss      5.000000
#         dagma-np   ER         20 gauss     10.000000
#         ges        ER         20 gauss     10.000000
#                                  mlp       10.000000
#         notears    ER         20 gauss     10.000000
#         notears-np ER         20 gauss     10.000000

# %%
group_df.count()
# Out:
#                                            name  _timestamp  tpr  _wandb  \
# d  n    model      graph_type s0 sem_type
# 10 1000 dagma-np   ER         20 gauss        1           1    0       0
#         ges        ER         20 gauss       11          11   11      11
#         notears-np ER         20 gauss        3           3    3       3
# 20 1000 dagma      ER         20 gauss       15          15   15      15
#         dagma-np   ER         20 gauss        1           1    0       0
#         ges        ER         20 gauss       20          20   20      20
#                                  mlp         20          20   20      20
#         notears    ER         20 gauss       15          15   15      15
#                                  mlp         10          10   10      10
#         notears-np ER         20 gauss        3           3    2       2
#                                  mlp         14          14   12      12
# 30 1000 dagma      ER         20 gauss        5           5    5       5
#         dagma-np   ER         20 gauss        1           1    0       0
#         ges        ER         20 gauss       20          20   20      20
#                                  mlp         10          10   10      10
#         notears    ER         20 gauss       10          10   10      10
#         notears-np ER         20 gauss        4           4    2       2
#
#                                            B_est_normalised  B_est  nnz  \
# d  n    model      graph_type s0 sem_type
# 10 1000 dagma-np   ER         20 gauss                    0      0    0
#         ges        ER         20 gauss                   11     11   11
#         notears-np ER         20 gauss                    3      3    3
# 20 1000 dagma      ER         20 gauss                   15     15   15
#         dagma-np   ER         20 gauss                    0      0    0
#         ges        ER         20 gauss                   20     20   20
#                                  mlp                     20     20   20
#         notears    ER         20 gauss                   15     15   15
#                                  mlp                     10     10   10
#         notears-np ER         20 gauss                    2      2    2
#                                  mlp                     12     12   12
# 30 1000 dagma      ER         20 gauss                    5      5    5
#         dagma-np   ER         20 gauss                    0      0    0
#         ges        ER         20 gauss                   20     20   20
#                                  mlp                     10     10   10
#         notears    ER         20 gauss                   10     10   10
#         notears-np ER         20 gauss                    2      2    2
#
#                                            fdr_normalised  DAG-diff  \
# d  n    model      graph_type s0 sem_type
# 10 1000 dagma-np   ER         20 gauss                  0         0
#         ges        ER         20 gauss                 11        10
#         notears-np ER         20 gauss                  3         0
# 20 1000 dagma      ER         20 gauss                 15         5
#         dagma-np   ER         20 gauss                  0         0
#         ges        ER         20 gauss                 20        10
#                                  mlp                   20        20
#         notears    ER         20 gauss                 15         5
#                                  mlp                   10         0
#         notears-np ER         20 gauss                  2         0
#                                  mlp                   12         0
# 30 1000 dagma      ER         20 gauss                  5         5
#         dagma-np   ER         20 gauss                  0         0
#         ges        ER         20 gauss                 20        10
#                                  mlp                   10        10
#         notears    ER         20 gauss                 10         0
#         notears-np ER         20 gauss                  2         0
#
#                                            nnz_normalised  fdr  shd  fpr  \
# d  n    model      graph_type s0 sem_type
# 10 1000 dagma-np   ER         20 gauss                  0    0    0    0
#         ges        ER         20 gauss                 11   11   11   11
#         notears-np ER         20 gauss                  3    3    3    3
# 20 1000 dagma      ER         20 gauss                 15   15   15   15
#         dagma-np   ER         20 gauss                  0    0    0    0
#         ges        ER         20 gauss                 20   20   20   20
#                                  mlp                   20   20   20   20
#         notears    ER         20 gauss                 15   15   15   15
#                                  mlp                   10   10   10   10
#         notears-np ER         20 gauss                  2    2    2    2
#                                  mlp                   12   12   12   12
# 30 1000 dagma      ER         20 gauss                  5    5    5    5
#         dagma-np   ER         20 gauss                  0    0    0    0
#         ges        ER         20 gauss                 20   20   20   20
#                                  mlp                   10   10   10   10
#         notears    ER         20 gauss                 10   10   10   10
#         notears-np ER         20 gauss                  2    2    2    2
#
#                                            _runtime  shd_normalised  \
# d  n    model      graph_type s0 sem_type
# 10 1000 dagma-np   ER         20 gauss            1               0
#         ges        ER         20 gauss           11              11
#         notears-np ER         20 gauss            3               3
# 20 1000 dagma      ER         20 gauss           15              15
#         dagma-np   ER         20 gauss            1               0
#         ges        ER         20 gauss           20              20
#                                  mlp             20              20
#         notears    ER         20 gauss           15              15
#                                  mlp             10              10
#         notears-np ER         20 gauss            3               2
#                                  mlp             14              12
# 30 1000 dagma      ER         20 gauss            5               5
#         dagma-np   ER         20 gauss            1               0
#         ges        ER         20 gauss           20              20
#                                  mlp             10              10
#         notears    ER         20 gauss           10              10
#         notears-np ER         20 gauss            4               2
#
#                                            tpr_normalised  _step  \
# d  n    model      graph_type s0 sem_type
# 10 1000 dagma-np   ER         20 gauss                  0      1
#         ges        ER         20 gauss                 11     11
#         notears-np ER         20 gauss                  3      3
# 20 1000 dagma      ER         20 gauss                 15     15
#         dagma-np   ER         20 gauss                  0      1
#         ges        ER         20 gauss                 20     20
#                                  mlp                   20     20
#         notears    ER         20 gauss                 15     15
#                                  mlp                   10     10
#         notears-np ER         20 gauss                  2      3
#                                  mlp                   12     14
# 30 1000 dagma      ER         20 gauss                  5      5
#         dagma-np   ER         20 gauss                  0      1
#         ges        ER         20 gauss                 20     20
#                                  mlp                   10     10
#         notears    ER         20 gauss                 10     10
#         notears-np ER         20 gauss                  2      4
#
#                                            fpr_normalised  methods  run_count
# d  n    model      graph_type s0 sem_type
# 10 1000 dagma-np   ER         20 gauss                  0        1          1
#         ges        ER         20 gauss                 11       11         11
#         notears-np ER         20 gauss                  3        3          3
# 20 1000 dagma      ER         20 gauss                 15       15         15
#         dagma-np   ER         20 gauss                  0        1          1
#         ges        ER         20 gauss                 20       20         20
#                                  mlp                   20       20         20
#         notears    ER         20 gauss                 15       15         15
#                                  mlp                   10       10         10
#         notears-np ER         20 gauss                  2        3          3
#                                  mlp                   12       14         14
# 30 1000 dagma      ER         20 gauss                  5        5          5
#         dagma-np   ER         20 gauss                  0        1          1
#         ges        ER         20 gauss                 20       20         20
#                                  mlp                   10       10         10
#         notears    ER         20 gauss                 10       10         10
#         notears-np ER         20 gauss                  2        4          4

# %%
for name, group in group_df:
    print(f"{name}")
    
    print((f"{round(group.shd_normalised.mean(), 3)} \\scriptsize{{({round(group.shd_normalised.std(), 3)})}} &"
           f"{round(group.shd.mean(), 3)} \\scriptsize{{({round(group.shd.std(), 3)})}} & "
           f"{round(group.fpr_normalised.mean(), 3)} \\scriptsize{{({round(group.fpr_normalised.std(), 3)})}} & "
           f"{round(group.fpr.mean(), 3)} \\scriptsize{{({round(group.fpr.std(), 3)})}} & "
           f"{round(group.tpr_normalised.mean(), 3)} \\scriptsize{{({round(group.tpr_normalised.std(), 3)})}} & "
           f"{round(group.tpr.mean(), 3)} \\scriptsize{{({round(group.tpr.std(), 3)})}} & "
           f"{round(group.fdr_normalised.mean(), 3)} \\scriptsize{{({round(group.fdr_normalised.std(), 3)})}} & "
           f"{round(group.fdr.mean(), 3)} \\scriptsize{{({round(group.fdr.std(), 3)})}} & "
           f"{round(group['DAG-diff'].mean(), 3)} \\scriptsize{{({round(group['DAG-diff'].std(), 3)})}}"))
    print("--------\n")
# Out:
# (10, 1000, 'dagma-np', 'ER', 20, 'gauss')
# nan \scriptsize{(nan)} &nan \scriptsize{(nan)} & nan \scriptsize{(nan)} & nan \scriptsize{(nan)} & nan \scriptsize{(nan)} & nan \scriptsize{(nan)} & nan \scriptsize{(nan)} & nan \scriptsize{(nan)} & nan \scriptsize{(nan)}
# --------
#
# (10, 1000, 'ges', 'ER', 20, 'gauss')
# 14.273 \scriptsize{(9.509)} &14.273 \scriptsize{(9.509)} & 0.436 \scriptsize{(0.346)} & 0.436 \scriptsize{(0.346)} & 0.632 \scriptsize{(0.242)} & 0.632 \scriptsize{(0.242)} & 0.421 \scriptsize{(0.285)} & 0.421 \scriptsize{(0.285)} & 0.0 \scriptsize{(0.0)}
# --------
#
# (10, 1000, 'notears-np', 'ER', 20, 'gauss')
# 20.0 \scriptsize{(1.732)} &1.667 \scriptsize{(2.082)} & 0.507 \scriptsize{(0.046)} & 0.027 \scriptsize{(0.046)} & 0.283 \scriptsize{(0.029)} & 0.933 \scriptsize{(0.076)} & 0.69 \scriptsize{(0.041)} & 0.035 \scriptsize{(0.061)} & nan \scriptsize{(nan)}
# --------
#
# (20, 1000, 'dagma', 'ER', 20, 'gauss')
# 11.933 \scriptsize{(3.262)} &0.467 \scriptsize{(0.834)} & 0.049 \scriptsize{(0.016)} & 0.003 \scriptsize{(0.005)} & 0.503 \scriptsize{(0.12)} & 0.987 \scriptsize{(0.023)} & 0.452 \scriptsize{(0.132)} & 0.022 \scriptsize{(0.04)} & 13.2 \scriptsize{(4.604)}
# --------
#
# (20, 1000, 'dagma-np', 'ER', 20, 'gauss')
# nan \scriptsize{(nan)} &nan \scriptsize{(nan)} & nan \scriptsize{(nan)} & nan \scriptsize{(nan)} & nan \scriptsize{(nan)} & nan \scriptsize{(nan)} & nan \scriptsize{(nan)} & nan \scriptsize{(nan)} & nan \scriptsize{(nan)}
# --------
#
# (20, 1000, 'ges', 'ER', 20, 'gauss')
# 0.8 \scriptsize{(2.441)} &0.8 \scriptsize{(2.441)} & 0.004 \scriptsize{(0.013)} & 0.004 \scriptsize{(0.013)} & 0.982 \scriptsize{(0.059)} & 0.982 \scriptsize{(0.059)} & 0.03 \scriptsize{(0.091)} & 0.03 \scriptsize{(0.091)} & 0.0 \scriptsize{(0.0)}
# --------
#
# (20, 1000, 'ges', 'ER', 20, 'mlp')
# 10.7 \scriptsize{(3.757)} &10.7 \scriptsize{(3.757)} & 0.03 \scriptsize{(0.023)} & 0.03 \scriptsize{(0.023)} & 0.673 \scriptsize{(0.118)} & 0.673 \scriptsize{(0.118)} & 0.249 \scriptsize{(0.141)} & 0.249 \scriptsize{(0.141)} & 0.0 \scriptsize{(0.0)}
# --------
#
# (20, 1000, 'notears', 'ER', 20, 'gauss')
# 14.533 \scriptsize{(1.807)} &0.533 \scriptsize{(0.64)} & 0.058 \scriptsize{(0.011)} & 0.001 \scriptsize{(0.002)} & 0.44 \scriptsize{(0.078)} & 0.973 \scriptsize{(0.032)} & 0.53 \scriptsize{(0.069)} & 0.01 \scriptsize{(0.021)} & 14.8 \scriptsize{(1.095)}
# --------
#
# (20, 1000, 'notears', 'ER', 20, 'mlp')
# 16.7 \scriptsize{(2.359)} &12.0 \scriptsize{(2.906)} & 0.029 \scriptsize{(0.017)} & 0.009 \scriptsize{(0.008)} & 0.235 \scriptsize{(0.12)} & 0.465 \scriptsize{(0.151)} & 0.504 \scriptsize{(0.2)} & 0.132 \scriptsize{(0.137)} & nan \scriptsize{(nan)}
# --------
#
# (20, 1000, 'notears-np', 'ER', 20, 'gauss')
# 23.0 \scriptsize{(4.243)} &0.5 \scriptsize{(0.707)} & 0.121 \scriptsize{(0.029)} & 0.003 \scriptsize{(0.004)} & 0.4 \scriptsize{(0.071)} & 0.975 \scriptsize{(0.035)} & 0.714 \scriptsize{(0.085)} & 0.025 \scriptsize{(0.035)} & nan \scriptsize{(nan)}
# --------
#
# (20, 1000, 'notears-np', 'ER', 20, 'mlp')
# 16.0 \scriptsize{(4.411)} &9.0 \scriptsize{(2.089)} & 0.057 \scriptsize{(0.03)} & 0.023 \scriptsize{(0.013)} & 0.475 \scriptsize{(0.114)} & 0.738 \scriptsize{(0.148)} & 0.473 \scriptsize{(0.184)} & 0.192 \scriptsize{(0.078)} & nan \scriptsize{(nan)}
# --------
#
# (30, 1000, 'dagma', 'ER', 20, 'gauss')
# 10.6 \scriptsize{(1.14)} &1.0 \scriptsize{(1.0)} & 0.023 \scriptsize{(0.003)} & 0.002 \scriptsize{(0.002)} & 0.59 \scriptsize{(0.065)} & 0.97 \scriptsize{(0.027)} & 0.449 \scriptsize{(0.052)} & 0.048 \scriptsize{(0.048)} & 11.2 \scriptsize{(1.304)}
# --------
#
# (30, 1000, 'dagma-np', 'ER', 20, 'gauss')
# nan \scriptsize{(nan)} &nan \scriptsize{(nan)} & nan \scriptsize{(nan)} & nan \scriptsize{(nan)} & nan \scriptsize{(nan)} & nan \scriptsize{(nan)} & nan \scriptsize{(nan)} & nan \scriptsize{(nan)} & nan \scriptsize{(nan)}
# --------
#
# (30, 1000, 'ges', 'ER', 20, 'gauss')
# 0.15 \scriptsize{(0.671)} &0.15 \scriptsize{(0.671)} & 0.0 \scriptsize{(0.002)} & 0.0 \scriptsize{(0.002)} & 0.997 \scriptsize{(0.011)} & 0.997 \scriptsize{(0.011)} & 0.007 \scriptsize{(0.03)} & 0.007 \scriptsize{(0.03)} & 0.0 \scriptsize{(0.0)}
# --------
#
# (30, 1000, 'ges', 'ER', 20, 'mlp')
# 8.2 \scriptsize{(2.573)} &8.2 \scriptsize{(2.573)} & 0.007 \scriptsize{(0.004)} & 0.007 \scriptsize{(0.004)} & 0.715 \scriptsize{(0.082)} & 0.715 \scriptsize{(0.082)} & 0.16 \scriptsize{(0.089)} & 0.16 \scriptsize{(0.089)} & 0.0 \scriptsize{(0.0)}
# --------
#
# (30, 1000, 'notears', 'ER', 20, 'gauss')
# 10.5 \scriptsize{(1.78)} &0.5 \scriptsize{(0.707)} & 0.022 \scriptsize{(0.003)} & 0.0 \scriptsize{(0.0)} & 0.54 \scriptsize{(0.061)} & 0.975 \scriptsize{(0.035)} & 0.459 \scriptsize{(0.058)} & 0.0 \scriptsize{(0.0)} & nan \scriptsize{(nan)}
# --------
#
# (30, 1000, 'notears-np', 'ER', 20, 'gauss')
# 18.0 \scriptsize{(0.0)} &1.5 \scriptsize{(2.121)} & 0.041 \scriptsize{(0.0)} & 0.004 \scriptsize{(0.005)} & 0.425 \scriptsize{(0.035)} & 0.95 \scriptsize{(0.071)} & 0.667 \scriptsize{(0.018)} & 0.071 \scriptsize{(0.101)} & nan \scriptsize{(nan)}
# --------

# %%
run_df['B_est'][3]

# %%
wandb.log?
